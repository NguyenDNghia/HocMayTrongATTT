# %%
# !apt-get install upx
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'upx-ucl' instead of 'upx'
# The following additional packages will be installed:
#   libucl1
# The following NEW packages will be installed:
#   libucl1 upx-ucl
# 0 upgraded, 2 newly installed, 0 to remove and 45 not upgraded.
# Need to get 479 kB of archives.
# After this operation, 2,176 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libucl1 amd64 1.03+repack-6 [25.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 upx-ucl amd64 3.96-3 [453 kB]
# Fetched 479 kB in 3s (187 kB/s)
# Selecting previously unselected package libucl1:amd64.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../libucl1_1.03+repack-6_amd64.deb ...
# Unpacking libucl1:amd64 (1.03+repack-6) ...
# Selecting previously unselected package upx-ucl.
# Preparing to unpack .../upx-ucl_3.96-3_amd64.deb ...
# Unpacking upx-ucl (3.96-3) ...
# Setting up libucl1:amd64 (1.03+repack-6) ...
# Setting up upx-ucl (3.96-3) ...
# update-alternatives: error: no alternatives for upx
# update-alternatives: using /usr/bin/upx-ucl to provide /usr/bin/upx (upx) in auto mode
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link

# %%
import os
from subprocess import Popen, PIPE

files_path = "/content/drive/MyDrive/Benign PE Samples UPX/"
files = os.listdir(files_path)
file_paths = [files_path + x for x in files]

cmd = "upx -d"

for path in file_paths:
    cmd2 = f'{cmd} "{path}"'
    process = Popen(cmd2, stdout=PIPE, stderr=PIPE, shell=True)
    output, errors = process.communicate()

    # Check for errors in output
    if "error" in output.decode() or errors:
        print(f"Error processing {path}: {errors.decode()}")
    else:
        print(f"Success: {output.decode()}")
# Out:
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     178688 <-     56832   31.81%    win32/pe     bitsadmin.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      52736 <-     31232   59.22%    win64/pe     BdeUISrv.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      67072 <-     33792   50.38%    win64/pe     bfsvc.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      43424 <-     31136   71.70%    win64/pe     browser_broker.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      82944 <-     37376   45.06%    win32/pe     bootcfg.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     138240 <-     73728   53.33%    win64/pe     BitLockerDeviceEncryption.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      25088 <-     17408   69.39%    win64/pe     bootim.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     107416 <-     49048   45.66%    win64/pe     bootsect.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      20480 <-     12800   62.50%    win64/pe     bridgeunattend.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      87968 <-     44960   51.11%    win64/pe     BrowserCore.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      49152 <-     25088   51.04%    win32/pe     AtBroker.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29184 <-     17408   59.65%    win32/pe     auditpol.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     139016 <-     70408   50.65%    win64/pe     AuthHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      79872 <-     40448   50.64%    win64/pe     audit.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     213504 <-     94208   44.12%    win64/pe     bcdboot.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19456 <-     11264   57.89%    win32/pe     attrib.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      30720 <-     17408   56.67%    win64/pe     AuditShD.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      34816 <-     15872   45.59%    win32/pe     BackgroundTransferHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      60416 <-     39424   65.25%    win64/pe     AxInstUI.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      17824 <-     16288   91.38%    win32/pe     backgroundTaskHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      22528 <-     13824   61.36%    win32/pe     ARP.EXE
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      69800 <-     42664   61.12%    win64/pe     ApplicationFrameHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      98912 <-     50272   50.82%    win32/pe     AppLaunch.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     160256 <-     68608   42.81%    win64/pe     appidpolicyconverter.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      20992 <-     11264   53.66%    win32/pe     appidtel.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      25088 <-     16384   65.31%    win32/pe     at.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19456 <-     13312   68.42%    win64/pe     appidcertstorecheck.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      47208 <-     34920   73.97%    win32/pe     aspnet_state.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      41064 <-     29800   72.57%    win32/pe     aspnet_regiis.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      91136 <-     50176   55.06%    win64/pe     alg.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      49181 <-     25117   51.07%    win64/pe     chmod.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      54813 <-     26653   48.63%    win64/pe     chown.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      30720 <-     16384   53.33%    win64/pe     CIDiag.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29464 <-     21784   73.93%    win32/pe     CameraSettingsUIHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      75680 <-     44448   58.73%    win64/pe     CloudExperienceHostBroker.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      90112 <-     65024   72.16%    win64/pe     CompMgmtLauncher.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      70864 <-     42704   60.26%    win64/pe     CastSrv.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     101280 <-     88992   87.87%    win64/pe     changepk.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      23552 <-     14336   60.87%    win64/pe     cofire.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      23552 <-     12288   52.17%    win32/pe     comp.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      48128 <-     28160   58.51%    win32/pe     ByteCodeGenerator.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      28160 <-     16896   60.00%    win32/pe     choice.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19968 <-     11264   56.41%    win32/pe     chkntfs.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      37888 <-     34816   91.89%    win32/pe     bthudtask.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      23040 <-     12288   53.33%    win32/pe     chkdsk.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      25088 <-     15872   63.27%    win32/pe     clip.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      61440 <-     48640   79.17%    win32/pe     ComputerDefaults.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      40960 <-     23040   56.25%    win32/pe     compact.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      14848 <-     10752   72.41%    win32/pe     comrepl.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      40448 <-     22528   55.70%    win32/pe     cipher.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      28672 <-     26112   91.07%    win32/pe     cliconfg.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      26112 <-     14848   56.86%    win32/pe     CheckNetIsolation.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      26112 <-     24064   92.16%    win32/pe     calc.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     167432 <-     82952   49.54%    win32/pe     CloudStorageWizard.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      66728 <-     40616   60.87%    win32/pe     CloudNotifications.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      17920 <-     12288   68.57%    win32/pe     cmdkey.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      82944 <-     37888   45.68%    win32/pe     cmstp.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      36864 <-     19968   54.17%    win32/pe     cmmon32.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      27648 <-     17408   62.96%    win32/pe     cacls.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      47104 <-     24064   51.09%    win32/pe     cmdl32.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     102400 <-     48640   47.50%    win64/pe     dmclient.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     171520 <-     76800   44.78%    win64/pe     dmcertinst.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     118968 <-     64696   54.38%    win32/pe     DismHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     123904 <-     55296   44.63%    win64/pe     dispdiag.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      38400 <-     21504   56.00%    win64/pe     dmcfghost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      10752 <-      8192   76.19%    win32/pe     dllhst3g.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      32256 <-     17920   55.56%    win64/pe     DmNotificationBroker.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19360 <-     16800   86.78%    win32/pe     dllhost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     286208 <-     97280   33.99%    win32/pe     diskraid.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      82944 <-     69632   83.95%    win32/pe     DevicePairingWizard.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      21504 <-     13824   64.29%    win32/pe     diskperf.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     150528 <-     62976   41.84%    win32/pe     diskpart.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      91136 <-     41472   45.51%    win64/pe     DiskSnapshot.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      32768 <-     18944   57.81%    win32/pe     dialer.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      78336 <-     40960   52.29%    win64/pe     DeviceCredentialDeployment.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      35232 <-     24480   69.48%    win64/pe     DeviceCensus.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29696 <-     24064   81.03%    win64/pe     DeviceEject.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      74752 <-     39424   52.74%    win64/pe     desktopimgdownldr.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     228760 <-    116120   50.76%    win64/pe     DataExchangeHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     132608 <-     64000   48.26%    win64/pe     DataUsageLiveTileTask.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      94208 <-     43008   45.65%    win64/pe     dasHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     184851 <-     45075   24.38%    win64/pe     cygrunsrv.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      35840 <-     22528   62.86%    win32/pe     cttunesvr.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      32768 <-     14336   43.75%    win32/pe     ddodiag.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#       9728 <-      7680   78.95%    win32/pe     ctfmon.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      10240 <-      7680   75.00%    win32/pe     dcomcnfg.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      43176 <-     32424   75.10%    win32/pe     cvtres.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     141312 <-     66048   46.74%    win64/pe     DataStoreCacheDumpTool.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     315296 <-    131488   41.70%    win64/pe     ConfigSecurityPolicy.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     114688 <-    109568   95.54%    win32/pe     control.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19456 <-     11264   57.89%    win32/pe     convert.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     143360 <-     74752   52.14%    win32/pe     cscript.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     287648 <-    104352   36.28%    win64/pe     CredDialogHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29696 <-     19456   65.52%    win32/pe     credwiz.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     157080 <-     94616   60.23%    win64/pe     consent.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     111152 <-     55856   50.25%    win32/pe     CredentialUIBroker.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      72192 <-     40960   56.74%    win64/pe     coredpussvr.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     209920 <-     94720   45.12%    win64/pe     convertvhd.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     326144 <-    118784   36.42%    win32/pe     esentutl.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      52736 <-     27136   51.46%    win32/pe     expand.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     120320 <-     75776   62.98%    win32/pe     EhStorAuthn.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      81408 <-     76288   93.71%    win32/pe     eventvwr.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      34304 <-     21504   62.69%    win32/pe     eventcreate.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29184 <-     17920   61.40%    win32/pe     extrac32.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      12800 <-      9216   72.00%    win32/pe     efsui.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      24605 <-     11805   47.98%    win64/pe     false.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      49664 <-     26112   52.58%    win32/pe     edpnotify.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      95232 <-     47616   50.00%    win64/pe     EduPrintProv.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     176640 <-     80384   45.51%    win32/pe     DWWIN.EXE
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      62976 <-     33792   53.66%    win64/pe     EASPolicyManagerBrokerHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      76528 <-     44784   58.52%    win64/pe     easinvoker.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     159232 <-     76288   47.91%    win64/pe     EDPCleanup.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      34816 <-     21504   61.76%    win64/pe     dusmtask.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      10752 <-      8192   76.19%    win32/pe     dvdplay.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      13312 <-     10240   76.92%    win64/pe     Eap3Host.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      17939 <-      8723   48.63%    win64/pe     editrights.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      62464 <-     34816   55.74%    win64/pe     dwm.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      45568 <-     26624   58.43%    win64/pe     dxgiadaptercache.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      67072 <-     33280   49.62%    win32/pe     driverquery.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     166912 <-     84480   50.61%    win64/pe     drvinst.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      77312 <-     42496   54.97%    win64/pe     drvcfg.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      16896 <-     10240   60.61%    win32/pe     doskey.exe
#
# Unpacked 1 file.
#
# ...
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      13824 <-      9728   70.37%    win32/pe     finger.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      14848 <-      9216   62.07%    win32/pe     find.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      24576 <-     14848   60.42%    win32/pe     fltMC.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      16896 <-     10240   60.61%    win32/pe     fixmapi.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      21240 <-     18168   85.54%    win64/pe     FirstLogonAnim.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      23040 <-     12288   53.33%    win32/pe     fc.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     275400 <-    115656   42.00%    win64/pe     LsaIso.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      97792 <-     41984   42.93%    win32/pe     logman.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      43008 <-     23040   53.57%    win32/pe     lodctr.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      86016 <-     45056   52.38%    win32/pe     logagent.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      68608 <-     35840   52.24%    win32/pe     makecab.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      43008 <-     24576   57.14%    win64/pe     lpremove.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     116253 <-     53789   46.27%    win64/pe     ls.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      40960 <-     21504   52.50%    win64/pe     lpkinstall.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      13312 <-     10240   76.92%    win64/pe     LogonUI.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      57976 <-     34424   59.38%    win64/pe     lsass.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     223744 <-    100352   44.85%    win64/pe     licensingdiag.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      66048 <-     36352   55.04%    win64/pe     LocationNotificationWindows.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     146776 <-     82264   56.05%    win64/pe     LicensingUI.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     200192 <-     84992   42.46%    win64/pe     LegacyNetUXHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      47600 <-     30192   63.43%    win64/pe     LockScreenContentServer.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      46080 <-     27136   58.89%    win64/pe     LicenseManagerShellext.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      33280 <-     18944   56.92%    win32/pe     LaunchWinApp.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      15891 <-      8211   51.67%    win64/pe     last.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      10752 <-      8704   80.95%    win64/pe     Locator.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      88408 <-     53592   60.62%    win64/pe     LockAppHost.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     150392 <-     73592   48.93%    win32/pe     junction.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      15360 <-      9728   63.33%    win32/pe     ktmutil.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     184832 <-     96768   52.35%    win64/pe     irftp.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29184 <-     16896   57.89%    win32/pe     ipconfig.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     150528 <-    128000   85.03%    win32/pe     iscsicli.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     107008 <-     83456   77.99%    win32/pe     isoburn.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      50688 <-     28160   55.56%    win64/pe     LanguageComponentsInstallerComHandler.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      15360 <-      9728   63.33%    win32/pe     label.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      37376 <-     22528   60.27%    win64/pe     ksetup.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      37376 <-     21504   57.53%    win64/pe     klist.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     288768 <-    121344   42.02%    win32/pe     imjpuexc.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     123904 <-     49152   39.67%    win32/pe     ieUnatt.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     140288 <-     89088   63.50%    win32/pe     IMESEARCH.EXE
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      16384 <-     10752   65.63%    win32/pe     icsunattend.exe
#
# Unpacked 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     268288 <-    125440   46.76%    win32/pe     IMEPADSV.EXE
#
# Unpacked 1 file.

# %%
import os
from subprocess import Popen, PIPE

files_path = "/content/drive/MyDrive/Benign PE Samples UPX/"
files = os.listdir(files_path)
file_paths = [files_path + x for x in files]

cmd = "upx"

for path in file_paths:
    cmd2 = f'{cmd} "{path}"'
    process = Popen(cmd2, stdout=PIPE, stderr=PIPE, shell=True)
    output, errors = process.communicate()

    # Check for errors in output
    if "error" in output.decode() or errors:
        print(f"Error processing {path}: {errors.decode()}")
    else:
        print(f"Success: {output.decode()}")
# Out:
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     178688 ->     56832   31.81%    win32/pe     bitsadmin.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      52736 ->     31232   59.22%    win64/pe     BdeUISrv.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      67072 ->     33792   50.38%    win64/pe     bfsvc.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      43424 ->     31136   71.70%    win64/pe     browser_broker.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      82944 ->     37376   45.06%    win32/pe     bootcfg.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     138240 ->     73728   53.33%    win64/pe     BitLockerDeviceEncryption.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      25088 ->     17408   69.39%    win64/pe     bootim.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     107416 ->     49048   45.66%    win64/pe     bootsect.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      20480 ->     12800   62.50%    win64/pe     bridgeunattend.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      87968 ->     44960   51.11%    win64/pe     BrowserCore.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      49152 ->     25088   51.04%    win32/pe     AtBroker.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29184 ->     17408   59.65%    win32/pe     auditpol.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     139016 ->     70408   50.65%    win64/pe     AuthHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      79872 ->     40448   50.64%    win64/pe     audit.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     213504 ->     94208   44.12%    win64/pe     bcdboot.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19456 ->     11264   57.89%    win32/pe     attrib.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      30720 ->     17408   56.67%    win64/pe     AuditShD.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      34816 ->     15872   45.59%    win32/pe     BackgroundTransferHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      60416 ->     39424   65.25%    win64/pe     AxInstUI.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      17824 ->     16288   91.38%    win32/pe     backgroundTaskHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      22528 ->     13824   61.36%    win32/pe     ARP.EXE
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      69800 ->     42664   61.12%    win64/pe     ApplicationFrameHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      98912 ->     50272   50.82%    win32/pe     AppLaunch.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     160256 ->     68608   42.81%    win64/pe     appidpolicyconverter.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      20992 ->     11264   53.66%    win32/pe     appidtel.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      25088 ->     16384   65.31%    win32/pe     at.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19456 ->     13312   68.42%    win64/pe     appidcertstorecheck.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      47208 ->     34920   73.97%    win32/pe     aspnet_state.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      41064 ->     29800   72.57%    win32/pe     aspnet_regiis.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      91136 ->     50176   55.06%    win64/pe     alg.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      49181 ->     25117   51.07%    win64/pe     chmod.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      54813 ->     26653   48.63%    win64/pe     chown.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      30720 ->     16384   53.33%    win64/pe     CIDiag.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29464 ->     21784   73.93%    win32/pe     CameraSettingsUIHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      75680 ->     44448   58.73%    win64/pe     CloudExperienceHostBroker.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      90112 ->     65024   72.16%    win64/pe     CompMgmtLauncher.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      70864 ->     42704   60.26%    win64/pe     CastSrv.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     101280 ->     88992   87.87%    win64/pe     changepk.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      23552 ->     14336   60.87%    win64/pe     cofire.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      23552 ->     12288   52.17%    win32/pe     comp.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      48128 ->     28160   58.51%    win32/pe     ByteCodeGenerator.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      28160 ->     16896   60.00%    win32/pe     choice.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19968 ->     11264   56.41%    win32/pe     chkntfs.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      37888 ->     34816   91.89%    win32/pe     bthudtask.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      23040 ->     12288   53.33%    win32/pe     chkdsk.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      25088 ->     15872   63.27%    win32/pe     clip.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      61440 ->     48640   79.17%    win32/pe     ComputerDefaults.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      40960 ->     23040   56.25%    win32/pe     compact.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      14848 ->     10752   72.41%    win32/pe     comrepl.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      40448 ->     22528   55.70%    win32/pe     cipher.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      28672 ->     26112   91.07%    win32/pe     cliconfg.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      26112 ->     14848   56.86%    win32/pe     CheckNetIsolation.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      26112 ->     24064   92.16%    win32/pe     calc.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     167432 ->     82952   49.54%    win32/pe     CloudStorageWizard.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      66728 ->     40616   60.87%    win32/pe     CloudNotifications.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      17920 ->     12288   68.57%    win32/pe     cmdkey.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      82944 ->     37888   45.68%    win32/pe     cmstp.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      36864 ->     19968   54.17%    win32/pe     cmmon32.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      27648 ->     17408   62.96%    win32/pe     cacls.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      47104 ->     24064   51.09%    win32/pe     cmdl32.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     102400 ->     48640   47.50%    win64/pe     dmclient.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     171520 ->     76800   44.78%    win64/pe     dmcertinst.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     118968 ->     64696   54.38%    win32/pe     DismHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     123904 ->     55296   44.63%    win64/pe     dispdiag.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      38400 ->     21504   56.00%    win64/pe     dmcfghost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      10752 ->      8192   76.19%    win32/pe     dllhst3g.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      32256 ->     17920   55.56%    win64/pe     DmNotificationBroker.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19360 ->     16800   86.78%    win32/pe     dllhost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     286208 ->     97280   33.99%    win32/pe     diskraid.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      82944 ->     69632   83.95%    win32/pe     DevicePairingWizard.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      21504 ->     13824   64.29%    win32/pe     diskperf.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     150528 ->     62976   41.84%    win32/pe     diskpart.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      91136 ->     41472   45.51%    win64/pe     DiskSnapshot.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      32768 ->     18944   57.81%    win32/pe     dialer.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      78336 ->     40960   52.29%    win64/pe     DeviceCredentialDeployment.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      35232 ->     24480   69.48%    win64/pe     DeviceCensus.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29696 ->     24064   81.03%    win64/pe     DeviceEject.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      74752 ->     39424   52.74%    win64/pe     desktopimgdownldr.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     228760 ->    116120   50.76%    win64/pe     DataExchangeHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     132608 ->     64000   48.26%    win64/pe     DataUsageLiveTileTask.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      94208 ->     43008   45.65%    win64/pe     dasHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     184851 ->     45075   24.38%    win64/pe     cygrunsrv.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      35840 ->     22528   62.86%    win32/pe     cttunesvr.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      32768 ->     14336   43.75%    win32/pe     ddodiag.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#       9728 ->      7680   78.95%    win32/pe     ctfmon.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      10240 ->      7680   75.00%    win32/pe     dcomcnfg.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      43176 ->     32424   75.10%    win32/pe     cvtres.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     141312 ->     66048   46.74%    win64/pe     DataStoreCacheDumpTool.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     315296 ->    131488   41.70%    win64/pe     ConfigSecurityPolicy.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     114688 ->    109568   95.54%    win32/pe     control.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      19456 ->     11264   57.89%    win32/pe     convert.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     143360 ->     74752   52.14%    win32/pe     cscript.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     287648 ->    104352   36.28%    win64/pe     CredDialogHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29696 ->     19456   65.52%    win32/pe     credwiz.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     157080 ->     94616   60.23%    win64/pe     consent.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     111152 ->     55856   50.25%    win32/pe     CredentialUIBroker.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      72192 ->     40960   56.74%    win64/pe     coredpussvr.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     209920 ->     94720   45.12%    win64/pe     convertvhd.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     326144 ->    118784   36.42%    win32/pe     esentutl.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      52736 ->     27136   51.46%    win32/pe     expand.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     120320 ->     75776   62.98%    win32/pe     EhStorAuthn.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      81408 ->     76288   93.71%    win32/pe     eventvwr.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      34304 ->     21504   62.69%    win32/pe     eventcreate.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29184 ->     17920   61.40%    win32/pe     extrac32.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      12800 ->      9216   72.00%    win32/pe     efsui.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      24605 ->     11805   47.98%    win64/pe     false.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      49664 ->     26112   52.58%    win32/pe     edpnotify.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      95232 ->     47616   50.00%    win64/pe     EduPrintProv.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     176640 ->     80384   45.51%    win32/pe     DWWIN.EXE
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      62976 ->     33792   53.66%    win64/pe     EASPolicyManagerBrokerHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      76528 ->     44784   58.52%    win64/pe     easinvoker.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     159232 ->     76288   47.91%    win64/pe     EDPCleanup.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      34816 ->     21504   61.76%    win64/pe     dusmtask.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      10752 ->      8192   76.19%    win32/pe     dvdplay.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      13312 ->     10240   76.92%    win64/pe     Eap3Host.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      17939 ->      8723   48.63%    win64/pe     editrights.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      62464 ->     34816   55.74%    win64/pe     dwm.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      45568 ->     26624   58.43%    win64/pe     dxgiadaptercache.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      67072 ->     33280   49.62%    win32/pe     driverquery.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     166912 ->     84480   50.61%    win64/pe     drvinst.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      77312 ->     42496   54.97%    win64/pe     drvcfg.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      16896 ->     10240   60.61%    win32/pe     doskey.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
# ...
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      13824 ->      9728   70.37%    win32/pe     finger.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      14848 ->      9216   62.07%    win32/pe     find.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      24576 ->     14848   60.42%    win32/pe     fltMC.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      16896 ->     10240   60.61%    win32/pe     fixmapi.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      21240 ->     18168   85.54%    win64/pe     FirstLogonAnim.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      23040 ->     12288   53.33%    win32/pe     fc.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     275400 ->    115656   42.00%    win64/pe     LsaIso.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      97792 ->     41984   42.93%    win32/pe     logman.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      43008 ->     23040   53.57%    win32/pe     lodctr.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      86016 ->     45056   52.38%    win32/pe     logagent.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      68608 ->     35840   52.24%    win32/pe     makecab.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      43008 ->     24576   57.14%    win64/pe     lpremove.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     116253 ->     53789   46.27%    win64/pe     ls.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      40960 ->     21504   52.50%    win64/pe     lpkinstall.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      13312 ->     10240   76.92%    win64/pe     LogonUI.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      57976 ->     34424   59.38%    win64/pe     lsass.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     223744 ->    100352   44.85%    win64/pe     licensingdiag.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      66048 ->     36352   55.04%    win64/pe     LocationNotificationWindows.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     146776 ->     82264   56.05%    win64/pe     LicensingUI.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     200192 ->     84992   42.46%    win64/pe     LegacyNetUXHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      47600 ->     30192   63.43%    win64/pe     LockScreenContentServer.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      46080 ->     27136   58.89%    win64/pe     LicenseManagerShellext.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      33280 ->     18944   56.92%    win32/pe     LaunchWinApp.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      15891 ->      8211   51.67%    win64/pe     last.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      10752 ->      8704   80.95%    win64/pe     Locator.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      88408 ->     53592   60.62%    win64/pe     LockAppHost.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     150392 ->     73592   48.93%    win32/pe     junction.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      15360 ->      9728   63.33%    win32/pe     ktmutil.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     184832 ->     96768   52.35%    win64/pe     irftp.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      29184 ->     16896   57.89%    win32/pe     ipconfig.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     150528 ->    128000   85.03%    win32/pe     iscsicli.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     107008 ->     83968   78.47%    win32/pe     isoburn.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      50688 ->     28160   55.56%    win64/pe     LanguageComponentsInstallerComHandler.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      15360 ->      9728   63.33%    win32/pe     label.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      37376 ->     22528   60.27%    win64/pe     ksetup.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      37376 ->     21504   57.53%    win64/pe     klist.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     288768 ->    121344   42.02%    win32/pe     imjpuexc.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     123904 ->     49152   39.67%    win32/pe     ieUnatt.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     140288 ->     89088   63.50%    win32/pe     IMESEARCH.EXE
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#      16384 ->     10752   65.63%    win32/pe     icsunattend.exe
#
# Packed 1 file.
#
# Success:                        Ultimate Packer for eXecutables
#                           Copyright (C) 1996 - 2020
# UPX 3.96        Markus Oberhumer, Laszlo Molnar & John Reiser   Jan 23rd 2020
#
#         File size         Ratio      Format      Name
#    --------------------   ------   -----------   -----------
#     268288 ->    125440   46.76%    win32/pe     IMEPADSV.EXE
#
# Packed 1 file.
